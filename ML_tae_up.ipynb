# %% [markdown]
# <a href="https://colab.research.google.com/github/AasthaNagargoje/Fraud-Detection-in-Insurance/blob/main/ML_tae_up.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# ML Libraries
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# Machine Learning Models
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b042effd-b69a-4fe6-bd6d-b80cc37ee2e7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b042effd-b69a-4fe6-bd6d-b80cc37ee2e7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('/content/Insurance_claims_data[1].csv')

df.head()
# Out:
#    policy_id  subscription_length  vehicle_age  customer_age region_code  \
# 0  POL045360                  9.3          1.2            41          C8
# 1  POL016745                  8.2          1.8            35          C2
# 2  POL007194                  9.5          0.2            44          C8
# 3  POL018146                  5.2          0.4            44         C10
# 4  POL049011                 10.1          1.0            56         C13
#
#    region_density segment model fuel_type     max_torque  ... is_brake_assist  \
# 0            8794      C2    M4    Diesel  250Nm@2750rpm  ...             Yes
# 1           27003      C1    M9    Diesel  200Nm@1750rpm  ...              No
# 2            8794      C2    M4    Diesel  250Nm@2750rpm  ...             Yes
# 3           73430       A    M1       CNG   60Nm@3500rpm  ...              No
# 4            5410      B2    M5    Diesel  200Nm@3000rpm  ...              No
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58592 entries, 0 to 58591
# Data columns (total 41 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   policy_id                         58592 non-null  object
#  1   subscription_length               58592 non-null  float64
#  2   vehicle_age                       58592 non-null  float64
#  3   customer_age                      58592 non-null  int64
#  4   region_code                       58592 non-null  object
#  5   region_density                    58592 non-null  int64
#  6   segment                           58592 non-null  object
#  7   model                             58592 non-null  object
#  8   fuel_type                         58592 non-null  object
#  9   max_torque                        58592 non-null  object
#  10  max_power                         58592 non-null  object
# ...

# %%
df = df.drop("policy_id", axis=1)

# %%
df['claim_status'].value_counts()
# Out:
# claim_status
# 0    54844
# 1     3748
# Name: count, dtype: int64

# %%
sns.countplot(x='claim_status', data=df)

plt.title("Fraud vs Non-Fraud Claims")

plt.show()

# %%
le = LabelEncoder()

for column in df.columns:
    if df[column].dtype == 'object':
        df[column] = le.fit_transform(df[column])

# %%
X = df.drop("claim_status", axis=1)

y = df["claim_status"]

# %%
scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

# %%
results_8020 = []
results_7030 = []

# Logistic Regression
# 80:20 Split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)
lr = LogisticRegression(max_iter=1000)
lr.fit(X_train, y_train)
acc_lr_80 = accuracy_score(y_test, lr.predict(X_test))
results_8020.append(['Logistic Regression', acc_lr_80])

# %%
print(results_8020)
# Out:
# [['Logistic Regression', 0.9363426913559177]]

# %%
# 70:30 Split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)
lr.fit(X_train, y_train)
acc_lr_70 = accuracy_score(y_test, lr.predict(X_test))
results_7030.append(['Logistic Regression', acc_lr_70])
print("Logistic Regression Accuracy (80:20):", acc_lr_80)
print("Logistic Regression Accuracy (70:30):", acc_lr_70)
# Out:
# Logistic Regression Accuracy (80:20): 0.9363426913559177
# Logistic Regression Accuracy (70:30): 0.934918648310388

# %%
print(results_7030)
# Out:
# [['Logistic Regression', 0.934918648310388]]

# %%
results_8020 = []
results_7030 = []

# 12: Decision Tree
# 80:20 Split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)
dt = DecisionTreeClassifier()
dt.fit(X_train, y_train)
acc_dt_80 = accuracy_score(y_test, dt.predict(X_test))
results_8020.append(['Decision Tree', acc_dt_80])

# %%
print(results_8020)
# Out:
# [['Decision Tree', 0.8711494154791365]]

# %%
# 70:30 Split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)
dt.fit(X_train, y_train)
acc_dt_70 = accuracy_score(y_test, dt.predict(X_test))
results_7030.append(['Decision Tree', acc_dt_70])
print("Decision Tree Accuracy (80:20):", acc_dt_80)
print("Decision Tree Accuracy (70:30):", acc_dt_70)
# Out:
# Decision Tree Accuracy (80:20): 0.8711494154791365
# Decision Tree Accuracy (70:30): 0.8667652747752873

# %%
# 13: Random Forest
# 80:20 Split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)
rf = RandomForestClassifier(n_estimators=100)
rf.fit(X_train, y_train)
acc_rf_80 = accuracy_score(y_test, rf.predict(X_test))
results_8020.append(['Random Forest', acc_rf_80])

# %%
# 70:30 Split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)
rf.fit(X_train, y_train)
acc_rf_70 = accuracy_score(y_test, rf.predict(X_test))
results_7030.append(['Random Forest', acc_rf_70])
print("Random Forest Accuracy (80:20):", acc_rf_80)
print("Random Forest Accuracy (70:30):", acc_rf_70)
# Out:
# Random Forest Accuracy (80:20): 0.9293455072958443
# Random Forest Accuracy (70:30): 0.9282626009784959

# %%
# 14: SVM
# 80:20 Split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)
svm = SVC()
svm.fit(X_train, y_train)
acc_svm_80 = accuracy_score(y_test, svm.predict(X_test))
results_8020.append(['SVM', acc_svm_80])

# %%
# 70:30 Split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)
svm.fit(X_train, y_train)
acc_svm_70 = accuracy_score(y_test, svm.predict(X_test))
results_7030.append(['SVM', acc_svm_70])
print("SVM Accuracy (80:20):", acc_svm_80)
print("SVM Accuracy (70:30):", acc_svm_70)
# Out:
# SVM Accuracy (80:20): 0.9363426913559177
# SVM Accuracy (70:30): 0.934918648310388

# %%
# 15: KNN
# 80:20 Split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train)
acc_knn_80 = accuracy_score(y_test, knn.predict(X_test))
results_8020.append(['KNN', acc_knn_80])

# %%
# 70:30 Split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)
knn.fit(X_train, y_train)
acc_knn_70 = accuracy_score(y_test, knn.predict(X_test))
results_7030.append(['KNN', acc_knn_70])
print("KNN Accuracy (80:20):", acc_knn_80)
print("KNN Accuracy (70:30):", acc_knn_70)
# Out:
# KNN Accuracy (80:20): 0.933782745968086
# KNN Accuracy (70:30): 0.9316190692911595

# %%
# 16: Naive Bayes
# 80:20 Split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)
nb = GaussianNB()
nb.fit(X_train, y_train)
acc_nb_80 = accuracy_score(y_test, nb.predict(X_test))
results_8020.append(['Naive Bayes', acc_nb_80])

# %%
# 70:30 Split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)
nb.fit(X_train, y_train)
acc_nb_70 = accuracy_score(y_test, nb.predict(X_test))
results_7030.append(['Naive Bayes', acc_nb_70])
print("Naive Bayes Accuracy (80:20):", acc_nb_80)
print("Naive Bayes Accuracy (70:30):", acc_nb_70)
# Out:
# Naive Bayes Accuracy (80:20): 0.9363426913559177
# Naive Bayes Accuracy (70:30): 0.934918648310388

# %%
# 17: Confusion Matrix (using the most recent test split)
cm = confusion_matrix(y_test, rf.predict(X_test))
sns.heatmap(cm, annot=True, fmt='d')
plt.title("Confusion Matrix - Random Forest")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
# 18: Precision, Recall, F1
print("Precision:", precision_score(y_test, rf.predict(X_test)))
print("Recall:", recall_score(y_test, rf.predict(X_test)))
print("F1 Score:", f1_score(y_test, rf.predict(X_test)))
# Out:
# Precision: 0.05343511450381679
# Recall: 0.006118881118881119
# F1 Score: 0.010980392156862745

# %%
# 19: Feature Importance
importances = rf.feature_importances_
feature_names = X.columns
feature_imp = pd.Series(importances, index=feature_names)
feature_imp.nlargest(10).plot(kind='barh')
plt.title("Top Important Features")
plt.show()

# %%
# --- Final Output Visualizations ---

# 1. Prepare data for plotting
df_8020 = pd.DataFrame(results_8020, columns=['Model', 'Accuracy'])
df_8020['Split'] = '80:20'

df_7030 = pd.DataFrame(results_7030, columns=['Model', 'Accuracy'])
df_7030['Split'] = '70:30'

# Combine both dataframes
df_combined = pd.concat([df_8020, df_7030])

# 2. Create Grouped Bar Chart
plt.figure(figsize=(12, 6))
sns.barplot(x='Model', y='Accuracy', hue='Split', data=df_combined, palette='viridis')

# Adding labels and styling
plt.title('Model Accuracy Comparison: 80:20 vs 70:30 Split', fontsize=15)
plt.xlabel('Machine Learning Model', fontsize=12)
plt.ylabel('Accuracy Score', fontsize=12)
plt.ylim(0, 1.1)  # Set y-axis limit to show full scale
plt.legend(title='Train:Test Split')
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Add text labels on top of the bars
for p in plt.gca().patches:
    plt.gca().annotate(f'{p.get_height():.3f}',
                       (p.get_x() + p.get_width() / 2., p.get_height()),
                       ha='center', va='center',
                       xytext=(0, 9),
                       textcoords='offset points',
                       fontsize=10)

plt.tight_layout()
plt.show()

# 3. (Optional) Heatmap for easier numerical comparison
pivot_df = df_combined.pivot(index='Model', columns='Split', values='Accuracy')
plt.figure(figsize=(8, 5))
sns.heatmap(pivot_df, annot=True, cmap='YlGnBu', fmt='.4f')
plt.title('Accuracy Heatmap Comparison')
plt.show()
